# %%
#import pandas as pd
import pickle
import seaborn; seaborn.set()
data = pickle.load(open('data.pkl','rb'))

# %% [markdown]
# # Speed

# %%
data['Speed'].plot(ylabel = 'Speed    (m/s)', xlabel= 'Time    (s)');
# Out:
# <AxesSubplot:xlabel='Time    (s)', ylabel='Speed    (m/s)'>

# %% [markdown]
# # Accelerator

# %%
data['Acc'].plot(ylabel = 'Acceleration    (0-250)', xlabel= 'Time    (s)');

# %% [markdown]
# # Brakes

# %%
data['Brake'].plot(ylabel = 'Breaking    (0-250)', xlabel= 'Time    (s)');

# %% [markdown]
# # Gears

# %%
data['Gear'].plot(ylabel = 'Gear', xlabel= 'Time    (s)');

# %% [markdown]
# # Steering

# %%
data['Steer'].plot(ylabel = 'Steering Angle', xlabel= 'Time    (s)');
